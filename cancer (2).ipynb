# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
plt.style.use('Solarize_Light2')

# %% [markdown]
# > # Data Analysis Content
# 1. Python Libraries
# 2. Data Content
# 3. Read and Analyse Data
# 4. Visualization
# 5. Predicting Risk using ML
# 6. Conclusion

# %% [markdown]
# # 1) Python Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
plt.style.use('Solarize_Light2')

# %%
df = pd.read_csv('../input/cancer-data-india/cancer_data.csv')
df.head(3)

# %% [markdown]
# # 2) Data Content
# > Wrangle, prepare, cleanse the data
#
# * Columns:
# 1.  cancer_type
# 2.  new_cases_num
# 3.  new_cases_rank
# 4.  new_case_percent
# 5.  death_num, Deaths Number
# 6.  death_rank
# 7.  death_percentage
# 8.  5-year prevalence (all ages) Cum.risk
# 9.  risk_of_prevalence_5yr
# 10. per100k_5yr_prevalence

# %% [markdown]
# # Which five forms of cancer are there? creating a new column using formal cancer
# >  There are five main types of cancer. These include:
# >
# A)Carcinoma. This type of cancer affects organs and glands, such as the lungs, breasts, pancreas and skin. Carcinoma is the most common type of cancer.
# >
# B)Sarcoma. This cancer affects soft or connective tissues, such as muscle, fat, bone, cartilage or blood vessels.
# >
# C)Melanoma. Sometimes cancer can develop in the cells that pigment your skin. These cancers are called melanoma.
# >
# D)Lymphoma. This cancer affects your lymphocytes or white blood cells.
# >
# E)Leukemia. This type of cancer affects blood.

# %%
# adding new column Cancer and renaming the old column["per100k_5yr_prevalence"] as Risk 
a=[]
for i in df["cancer_type"]:
    if i=="Brain, central nervous system":
        b="Carcinoma"
        a.append(b)
    elif i=="Breast":
        b="Carcinoma"
        a.append(b)
    elif i=="Vulva":
        b="Carcinoma"
        a.append(b)
    elif i=="Melanoma of skin":
        b="Carcinoma"
        a.append(b)
    elif i=="Pancreas":
        b="Carcinoma"
        a.append(b)
    elif i=="Larynx":
        b="Carcinoma"
        a.append(b)
    elif i=="Larynx":
        b="Carcinoma"
        a.append(b)
    elif i=="Vagina":
        b="Carcinoma"
        a.append(b)
    elif i=="Testis":
        b="Carcinoma"
        a.append(b)
    elif i=="Anus":
        b="Carcinoma"
        a.append(b)
    elif i=="Bladder":
        b="Sarcoma"
        a.append(b)
    elif i=="Anus":
        b="Carcinoma"
        a.append(b)
    elif i=="Cervix uteri":
        b="Carcinoma"
        a.append(b)
    elif i=="Colon":
        b="Carcinoma"
        a.append(b)
    elif i=="Corpus uteri":
        b="Sarcoma"
        a.append(b)
    elif i=="Gallbladder":
        b="Carcinoma"
        a.append(b)
    elif i=="Hodgkin lymphoma":
        b="Lymphoma"
        a.append(b)
    elif i=="Hypopharynx":
        b="Carcinoma"
        a.append(b)
    elif i=="Kaposi sarcoma":
        b="Lymphoma"
        a.append(b)
    elif i=="Kidney":
        b="Carcinoma"
        a.append(b)
    elif i=="Leukaemia":
        b="Leukaemia"
        a.append(b)
    elif i=="Lip, oral cavity":
        b="Carcinoma"
        a.append(b)
    elif i=="Liver":
        b="Carcinoma"
        a.append(b)
    elif i=="Lung":
        b="Carcinoma"
        a.append(b)
    elif i=="Melanoma of skin":
        b="Carcinoma"
        a.append(b)
    elif i=="Mesothelioma":
        b="Carcinoma"
        a.append(b)
    elif i=="Multiple myeloma":
        b="Sarcoma"
        a.append(b)
    elif i=="Nasopharynx":
        b="Carcinoma"
        a.append(b)
    elif i=="Non-Hodgkin lymphoma":
        b="Lymphoma"
        a.append(b)
    elif i=="Oesophagus":
        b="Carcinoma"
        a.append(b)
    elif i=="Oropharynx":
        b="Carcinoma"
        a.append(b)
    elif i=="Ovary":
        b="Carcinoma"
        a.append(b)
    elif i=="Prostate":
        b="Sarcoma"
        a.append(b)
    elif i=="Pancreas":
        b="Carcinoma"
        a.append(b)
    elif i=="Penis":
        b="Carcinoma"
        a.append(b)
    elif i=="Salivary glands":
        b="Sarcoma"
        a.append(b)
    elif i=="Rectum":
        b="Carcinoma"
        a.append(b)
    elif i=="Vagina":
        b="Carcinoma"
        a.append(b)
    elif i=="Thyroid":
        b="Sarcoma"
        a.append(b)
    elif i=="Stomach":
        b="Carcinoma"
        a.append(b)
    elif i=="Testis":
        b="Carcinoma"
        a.append(b)
#print(a)
df['cancer'] = a 
#Renaming
df.rename(columns={'per100k_5yr_prevalence':'Risk'},inplace=True)
#df.dtypes

df.head(3)

# %%
df.info()
# calculate duplicates
dups = df.duplicated()
# report if there are any duplicates
print(dups.any())
# list all duplicate rows
print(df[dups])
#Cardinality 
df.nunique() # To determine the maximum and minimum number of variations in each column of the dataset
#Lets now check for null fields
import seaborn as sns
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
df.isnull().sum()

# %% [markdown]
# > obseravation
#
# NOTHING is missing

# %%
#Cancertype has high risk(Top 5)
df.sort_values(by=['Risk'],ascending=False)['cancer_type'].head(5)

# %% [markdown]
# # 3. Read and Analyse Data

# %%
df.describe().T.style.bar(subset=['mean'], color='#205ff2')\
                            .background_gradient(subset=['std'], cmap='Reds')\
                            .background_gradient(subset=['50%'], cmap='coolwarm')

# %%
print(df.max())

# %%
df.hist(bins=10, figsize=(16, 10))
plt.tight_layout()

# %% [markdown]
# # 4. Visualization

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True, linewidths=.5, fmt= '.1f',ax=ax);

# %% [markdown]
# > Using a countplote to draw meaningful conclusions from the counting of different values****

# %%
# Verifying the cancer 
plt.figure(figsize=(12,10))
sns.countplot(data=df,x = 'cancer',palette='plasma')

# %% [markdown]
# > Obseravation:
#
# Carsinoma accounts for the majority of cancer cases; it affects glands and organs including the skin, lungs, breasts, and pancreas. The most typical sort of cancer is a carcinoma.

# %%
fig = plt.figure(figsize=(27,18))

sub1 = fig.add_subplot(3,3,1)
sub1.set_xlabel('cancer_type')
sub1.set_title('Risk')
df.groupby('cancer_type').sum()['Risk'].plot(linewidth=4,color='blue', linestyle='dashed')
plt.legend(bbox_to_anchor=(1, 1), loc=1)

sub1 = fig.add_subplot(3,3,2)
sub1.set_xlabel('cancer_type')
sub1.set_title('death_rank')
df.groupby('cancer_type').sum()['death_rank'].plot(linewidth=4, color='red', linestyle='dashed')
plt.legend(bbox_to_anchor=(1, 1), loc=1)

sub1 = fig.add_subplot(3,3,3)
sub1.set_xlabel('cancer_type')
sub1.set_title('Deaths Number')
df.groupby('cancer_type').sum()['Deaths Number'].plot(linewidth=4, color = 'green', linestyle='dashed')
plt.legend(bbox_to_anchor=(1, 1), loc=1)

sub1 = fig.add_subplot(3,3,4)
sub1.set_xlabel('cancer_type')
sub1.set_title('new_cases_number')
df.groupby('cancer_type').sum()['new_cases_number'].plot(linewidth=4, color = 'blue', linestyle='dashed')
plt.legend(bbox_to_anchor=(1, 1), loc=1)

sub1 = fig.add_subplot(3,3,5)
sub1.set_xlabel('cancer_type')
sub1.set_title('new_cases_rank')
df.groupby('cancer_type').sum()['new_cases_rank'].plot(linewidth=4, color = 'red', linestyle='dashed')
plt.legend(bbox_to_anchor=(1, 1), loc=1)

sub1 = fig.add_subplot(3,3,6)
sub1.set_xlabel('cancer_type')
sub1.set_title('death_percentage')
df.groupby('cancer_type').sum()['death_percentage'].plot(linewidth=4, color = 'green', linestyle='dashed')
plt.legend(bbox_to_anchor=(1, 1), loc=1)

sub1 = fig.add_subplot(3,3,7)
sub1.set_xlabel('cancer_type')
sub1.set_title('new_case_percent')
df.groupby('cancer_type').sum()['new_case_percent'].plot(linewidth=4, color = 'blue', linestyle='dashed')
plt.legend(bbox_to_anchor=(1, 1), loc=1)

# %% [markdown]
# > Obseravation:
#
# When all columns are plotted while taking the type of cancer into account, it is clear that there is a pattern that is quite similar in the Risk column with the new cases number and new case percent as well as the death percentage column with the Deaths Number column.

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.express as ex

# %%
# contrasting the orbit height and orbit type (km)
ex.box(x = 'cancer_type', y = 'Risk',data_frame = df, template='seaborn', 
       notched=True, width=800, height=750)

# %% [markdown]
# > Obseravation:
#
# Breast, cervix, and uterus cancers pose the greatest risk.>> Lip, mouth, ovary, and prostate

# %%
# 
ex.box(x = 'cancer', y = 'Deaths Number',data_frame = df, template='seaborn', 
       notched=True, width=800, height=500)

# %% [markdown]
# > Obseravation:
#
#  Cancer death number in Carcinoma > Lymphoma and Sarcoma ,Leukemia.

# %%
ex.box(x = 'cancer', y = 'Risk',data_frame = df, template='seaborn', 
       notched=True, width=800, height=500)

# %% [markdown]
# >Obseravation:
#
# Cancer Risk rate in Carcinoma > Sarcoma and Lymphoma.

# %%
#new_case vs Death_number
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['risk_of_prevalence_5yr'],y=df['Risk'])

# %% [markdown]
# >Obseravation:
#
# Death risk gradually rises as year increases.

# %%
#new_case vs Death_number
plt.figure(figsize=(6,6))
sns.scatterplot(x=df['new_cases_number'],y=df['Deaths Number'])

# %% [markdown]
# >Obseravation:
#
# Death rates gradually rise as a result of new case numbers and saturation

# %% [markdown]
# # 5. Predicting Risk using ML

# %%
#ML_Model

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['cancer_type'] = encoder.fit_transform(df['cancer_type'])
df['cancer_type'].unique()

# %%
#predicting Risk
#Spilt into Train_Test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=0)

# %%
#selecting features
y = df['Risk']
x = df.drop(['Risk',"cancer"],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=0)

# %%
#Model Building
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=1)
regressor.fit(x_train,y_train)
y_pred = regressor.predict(x_test)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
mse
print("RMSE: ", mse**(1/2.0),"MSE: ",mse)

# %%
#Vis Results
x_ax = range(len(y_test))
plt.figure(figsize=(10,8))
plt.plot(x_ax, y_test, linewidth=1, label="original",color = 'red')
plt.plot(x_ax, y_pred, linewidth=1.1, label="predicted")
plt.title("y-test and y-predicted data")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
#using MultipleLinearRegression
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
mse
print("RMSE: ", mse**(1/2.0),"MSE: ",mse)

# %%
#Vis Results
x_ax = range(len(y_test))
plt.figure(figsize=(10,8))
plt.plot(x_ax, y_test, linewidth=1, label="original",color = 'red')
plt.plot(x_ax, y_pred, linewidth=1.1, label="predicted")
plt.title("y-test and y-predicted data")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %% [markdown]
# # 6. Conclusion:
#
# Death rates gradually increase as a result of increased case numbers of cases.
# 1) Carcinoma has a higher cancer risk than sarcoma and lymphoma.
# 2) More people die Carcinoma than leukaemia, lymphoma, or sarcoma.
# (Cancers of the mouth, lips, cervix, ovary, and uterus are the most dangerous.)
# The majority of cancer instances are caused by carcinomas, which can affect glands and organs such the skin, lungs, breasts, and pancreas. A carcinoma is the type of cancer that is most common.
